# %% [markdown]
# ## Load libraries

# %%
import gnssvod as gv
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
import matplotlib.dates as mdates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gnssvod as gv
#       2 import pandas as pd
#       3 import xarray as xr
#
# File ~/Library/Python/3.9/lib/python/site-packages/gnssvod/__init__.py:3
#       1 from .io.preprocess import preprocess, gather_stations
#       2 from .analysis.vod_calc import calc_vod
# ----> 3 from .hemistats.hemistats import hemibuild
#
# File ~/Library/Python/3.9/lib/python/site-packages/gnssvod/hemistats/hemistats.py:15
#      13 import multiprocessing
#      14 import pdb
# ---> 15 from matplotlib.patches import Rectangle, Circle
#      16 # ===========================================================
#      17 """
#      18 Class definition for hemispheric polar grid object
#      19 """
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Load data
#
# Open the dataset you want to plot SNR. Do it by period, so it can be visualized dry season versus wet season. Do separate folders for each forest cover

# %%
# load dry season data
dry_season = xr.open_mfdataset('/Users/vargasgg/Library/CloudStorage/Box-Box/Project_HorizontesGNSS/Data/nc_files/PACQUI/DrySeasonnc/*.nc',combine='nested',concat_dim='Epoch')

# load wet season data
wet_season = xr.open_mfdataset('/Users/vargasgg/Library/CloudStorage/Box-Box/Project_HorizontesGNSS/Data/nc_files/PACQUI/WetSeasonnc/*.nc',combine='nested',concat_dim='Epoch')
